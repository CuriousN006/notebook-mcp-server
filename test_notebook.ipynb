# %% [markdown]
# # 테스트 노트북
#
# notebook-mcp-server 새 기능 테스트용

# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %% [markdown]
# import pandas as pd
# import numpy as np
# from datetime import datetime

# %%
# 변수 정의
df = pd.DataFrame({'a': [1, 2, 3], 'b': [4, 5, 6]})
model = None
result = 42

print('Hello, World!')
# Out:
# Hello, World!

# %%
def calculate_sum(a, b):
    """두 수의 합을 반환"""
    return a + b

class DataProcessor:
    def __init__(self):
        self.data = []
    
    def process(self):
        pass

# %%
df
# Out:
#    a  b
# 0  1  4
# 1  2  5
# 2  3  6
